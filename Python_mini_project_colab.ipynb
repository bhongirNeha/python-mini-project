# %% [markdown]
# <a href="https://colab.research.google.com/github/bhongirNeha/python-mini-project/blob/main/Python_mini_project_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries:
# Pandas for Data handling
# Numpy for Numerical Data handling
# Plotly for interactive plots.

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# Loading the dataset

# %%
df = px.data.iris()
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %% [markdown]
# #PART 1: Dataset Exploration

# %% [markdown]
# ##TASK 1

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %% [markdown]
# ##Head()gives first five records

# %% [markdown]
# ##TASK 2

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3

# %% [markdown]
# ## Tail() gives last 5 records

# %% [markdown]
# ##TASK 3

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# ##Shape gives the dimensions of the data.

# %% [markdown]
# ##TASK 4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
#  5   species_id    150 non-null    int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ##info() gives the information of the data.

# %% [markdown]
# ##TASK 5

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species',
#        'species_id'],
#       dtype='object')

# %% [markdown]
# ## Gives the column names.

# %% [markdown]
# ##TASK 6

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# species_id        int64
# dtype: object

# %% [markdown]
# ##Types gives the data types.

# %% [markdown]
# #PART 2: DATA ANALYSIS

# %% [markdown]
# ##TASK 1

# %%
print('Average sepal length:', np.mean(df['sepal_length']))
# Out:
# Average sepal length: 5.843333333333334

# %% [markdown]
# ##Gives the mean of the sepal length across all the species.

# %% [markdown]
# ##TASK 2

# %%
print('Average petal length:', np.mean(df['petal_length']))
# Out:
# Average petal length: 3.758666666666666

# %% [markdown]
# ##Gives the mean of the petal length in the dataset.

# %% [markdown]
# ##TASK 3

# %%
print('Maximum sepal length:', np.max(df['sepal_length']))
# Out:
# Maximum sepal length: 7.9

# %% [markdown]
# ## Gives the maximum sepal length in the data.

# %% [markdown]
# ##TASK 4

# %%
print('Minimum petal width:', np.min(df['petal_width']))
# Out:
# Minimum petal width: 0.1

# %% [markdown]
# ##Gives the minimum petal width of the data.

# %% [markdown]
# ##TASK 5

# %%
print('Total no of flower species:', len(df['species']))
# Out:
# Total no of flower species: 150

# %% [markdown]
# ## This cell gives the total number of flower species.

# %% [markdown]
# ##TASK 6

# %%
print('species count:', df['species'].value_counts())
# Out:
# species count: species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## This code gives count of each species.

# %% [markdown]
# #PART 3: Numpy Practice

# %%
sepal_length_array = np.array(df['sepal_length'])
sepal_length_array
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])

# %% [markdown]
# ## The sepal length column is converted into an array.

# %%
petal_length_array = np.array(df['petal_length'])
petal_length_array
# Out:
# array([1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
#        1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1. , 1.7, 1.9, 1.6,
#        1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.5, 1.3,
#        1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4, 4.7, 4.5,
#        4.9, 4. , 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4. , 4.7, 3.6,
#        4.4, 4.5, 4.1, 4.5, 3.9, 4.8, 4. , 4.9, 4.7, 4.3, 4.4, 4.8, 5. ,
#        4.5, 3.5, 3.8, 3.7, 3.9, 5.1, 4.5, 4.5, 4.7, 4.4, 4.1, 4. , 4.4,
#        4.6, 4. , 3.3, 4.2, 4.2, 4.2, 4.3, 3. , 4.1, 6. , 5.1, 5.9, 5.6,
#        5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5. , 5.1, 5.3, 5.5,
#        6.7, 6.9, 5. , 5.7, 4.9, 6.7, 4.9, 5.7, 6. , 4.8, 4.9, 5.6, 5.8,
#        6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1,
#        5.9, 5.7, 5.2, 5. , 5.2, 5.4, 5.1])

# %% [markdown]
# ##The petal length column is converted into an array.

# %% [markdown]
# ##TASK 1

# %%
average = np.mean(sepal_length_array)
print('Average sepal length:', average)
average_petal_length = np.mean(petal_length_array)
print('Average petal length:', average_petal_length)
# Out:
# Average sepal length: 5.843333333333334
# Average petal length: 3.758666666666666

# %% [markdown]
# ##The mean of sepal and petal length in the array is calculated.

# %% [markdown]
# ##TASK 2

# %%
median = np.median(sepal_length_array)
print('median of sepal length:', median)
median_petal_length = np.median(petal_length_array)
print('median of petal length:', median_petal_length)
# Out:
# median of sepal length: 5.8
# median of petal length: 4.35

# %% [markdown]
# ## The median of sepal and petal length is calculated in array.

# %% [markdown]
# ##TASK 3

# %%
maximum = np.max(sepal_length_array)
print('maximum of sepal length:', maximum)
maximum_petal_length = np.max(petal_length_array)
print('maximum of petal length:', maximum_petal_length)
# Out:
# maximum of sepal length: 7.9
# maximum of petal length: 6.9

# %% [markdown]
# ##The maximum value of sepal and petal length in array is calculated using np.max.

# %% [markdown]
# ##TASK 4

# %%
minimum = np.min(sepal_length_array)
print('minimum of sepal length:', minimum)
minimum_petal_length = np.min(petal_length_array)
print('minimum of petal length:', minimum_petal_length)
# Out:
# minimum of sepal length: 4.3
# minimum of petal length: 1.0

# %% [markdown]
# ##The minimum value of sepal and petal length is calculated in array using np.min

# %% [markdown]
# ##TASK 5

# %%
deviation = np.std(sepal_length_array)
print('Standard deviation of sepal length:', deviation)
deviation_petal_length = np.std(petal_length_array)
print('Standard deviation of petal length:', deviation_petal_length)
# Out:
# Standard deviation of sepal length: 0.8253012917851409
# Standard deviation of petal length: 1.7585291834055212

# %% [markdown]
# ##The standard deviation of sepal and petal length in the array is calculated using np.std code.

# %% [markdown]
# #PART 4: Visualization using Matplotlib

# %% [markdown]
# ##Matplotlib is imported for plotting graphs.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##CHART 1-LINE CHART

# %% [markdown]
# The dimensions of graph size is mentioned in the 1st line of the code. The second line describes about the index and the column name, 'x' is the marker given to print the points in the graph.Title,xlabel and ylabel are given.

# %%
plt.figure(figsize=(8,4))
plt.plot(df.index, df['sepal_length'], marker = 'x')
plt.title('Sepal Length Line Chart')
plt.xlabel('Index')
plt.ylabel('Sepal Length')
plt.show()

# %% [markdown]
# ###INTERPRETATION
# Line chart shows the trend.The above graph is depicting the trend of sepal length across all the species in the data.The length of the sepal is varing among the species.

# %% [markdown]
# ##TASK 2 BAR CHART

# %% [markdown]
# Value counts() gives the total species counts.

# %%
species_count= df['species'].value_counts()
species_count
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# The dimensions,title,xlabel and ylabel are given.The second line code accesses the index and count of species in frequency table.

# %%
plt.figure(figsize=(8,4))
plt.bar(species_count.index,species_count)
plt.title(' Total Species Count')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### INTERPRETATION
# Bar chart is used for the categorical data. The graph shows total species count for each species.Here, the 3 species have same counts of around 50.

# %% [markdown]
# ##TASK 3-SCATTER PLOT

# %% [markdown]
# Here the extra code called grid is given so that the grid is displayed in the graph so that the data points can be analysed accurately in the range it is falling in.

# %%
plt.figure(figsize=(8,4))
plt.scatter(df['sepal_length'], df['petal_length'])
plt.title('Sepal Length vs Petal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.grid(True)
plt.show()

# %% [markdown]
# ###INTERPRETATION
# The above Scatter plot shows the correlation between sepal length and petal length of all the species.One of the species is falling in lower range and the rest species are falling in the higher ranges.

# %% [markdown]
# ##CHART 4- Histogram

# %% [markdown]
# Bins is extra code we give in Histogram from the rest of the common codes for the graphs.This code divides the data into 20 parts.

# %%
plt.figure(figsize=(8,4))
plt.hist(df['sepal_width'], bins=20)
plt.title('Distribution of Sepal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### INTERPRETATION
#
# Histogram shows the distribution of the data. The above shows the distribution of sepal width across all the species in the data.Sepal width is varying among different species.

# %% [markdown]
# #PART 5: Visualization using plotly

# %% [markdown]
# ##CHART 1-Interactive Scatter plot

# %% [markdown]
# In plotly instead of x & y labels the column names from the dataframe are assigned directly to x and y axis.The code show() displays the graph.

# %%
fig = px.scatter(
    df,
    x='sepal_length',
    y='petal_length',
    color='species',
    title='Interactive Scatter Plot'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###INTERPRETATION
#
# Scatter plot gives the correlation between the variables. The spread of the data can be observed in the above plot were there are outliers and overlapping points present.Here,the relation between the sepal and petal length is seen.Setosa species have smaller petal and sepal length when compared to versicolor and virginica.Virginica shows larger petal and sepal length.

# %% [markdown]
# ##CHART 2-BOX PLOT

# %% [markdown]
# In box plot, color is given to represent different species with different colors.

# %%
fig = px.box(
    df,
    x='species',
    y='petal_length',
    color='species',
    title='Box Plot of Petal length by Species'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###INTERPRETATION
#
# Box plot is used to analyze the outliers.The graph shows the petal length across all the species.Outliers for versicolor and setosa species are observed.Rest of the data points are falling within the range.

# %% [markdown]
# ## CHART 3-Histogram

# %%
fig = px.histogram(
    df,
    x='sepal_length',
    nbins=20,
    title='Distribution of Sepal Length'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###INTERPRETATION
# Histogram shows the frequency distribution of the data.The graph shows the distribution of sepal length across all species.Here,the data seems to look like it is slightly going beyond the normal distribution in the initial points.

# %% [markdown]
# ##CHART 4-PIE CHART

# %% [markdown]
# Here the reset index gives the new column starting from 0 in the frequency table and the total counts are calculated.

# %%
species_dist = df['species'].value_counts().reset_index()
species_dist
# Out:
#       species  count
# 0      setosa     50
# 1  versicolor     50
# 2   virginica     50

# %% [markdown]
# The column names are reassigned.

# %%
species_dist.columns=['species', 'count']

# %% [markdown]
# The species names to be displayed are defined in 'names' and percentage to be displayed are defined in'count'.

# %%
fig = px.pie(
    species_dist,
    names = 'species',
    values = 'count',
    title = 'Distribution of Species'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###INTERPRETATION
# Pie chart represents the proportion of categorical data.The above graph shows the total species count.And it shows that they are equal counts for each species.

# %% [markdown]
# #PART 6: Python Fundamentals

# %%
marks = [78,82,91,65,88]
marks
# Out:
# [78, 82, 91, 65, 88]

# %% [markdown]
# ##TASK 1

# %%
marks.append(100)
marks
# Out:
# [78, 82, 91, 65, 88, 100]

# %% [markdown]
# append is used to add a number to the list.

# %% [markdown]
# ##TASK 2

# %%
marks.remove(91)
marks
# Out:
# [78, 82, 65, 88, 100]

# %% [markdown]
# remove code is used to remove a number from list.

# %% [markdown]
# ##TASK 3

# %%
marks.sort(reverse = False)
marks
# Out:
# [65, 78, 82, 88, 100]

# %% [markdown]
# sort(reverse = False) code prints the numbers in the list in the ascending order.

# %% [markdown]
# ##TASK 4

# %%
highest_marks = np.max(marks)
print('Highest_marks:', highest_marks)
# Out:
# Highest_marks: 100

# %% [markdown]
# np.max prints the highest marks in the list.

# %% [markdown]
# ##TASK 5

# %%
lowest_marks = np.min(marks)
print('Lowest_marks:', lowest_marks)
# Out:
# Lowest_marks: 65

# %% [markdown]
# np.min prints the lowest marks in the list.
